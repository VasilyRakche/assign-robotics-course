# %%
def solve_komo_IK_grasping():
    IK = C.komo_IK(False)

    # encode grasping
    IK.addObjective([1.], 
                    ry.FS.positionRel, 
                    ["object", "R_gripperCenter"], 
                    ry.OT.eq, 
                    1e2,
                    [0.,0.,.0]);

    IK.addObjective([1.], 
                    ry.FS.quaternionRel, 
                    ["object", "R_gripperCenter"], 
                    ry.OT.eq, 
                    [1e2],
                    [.707,.707,0,0]);


    IK.optimize()
#     IK.getReport()
    return IK.getPathFrames()  

def solve_komo_IK_grasping_relative():
    IK = C.komo_IK(False)

    # encode grasping
    IK.addObjective([1.], 
                    ry.FS.positionRel, 
                    ["object", "R_gripperCenter"], 
                    ry.OT.eq, 
                    1e2,
                    [0.,0.,.0]);

    IK.addObjective([0.7, 1.], 
                    ry.FS.scalarProductXZ, 
                    ["R_gripperCenter", "object"], 
                    ry.OT.eq, 
                    [1e2],
                    [0.])

    IK.addObjective([0.7, 1.], 
                    ry.FS.scalarProductZ, 
                    ["R_gripperCenter", "world"], 
                    ry.OT.eq, 
                    [1e2],
                    [0.])

    IK.optimize()
#     IK.getReport()
    return IK.getPathFrames()

# %%
import sys
sys.path.append('../../build')
import numpy as np
import libry as ry
import time
import cv2 as cv

#Let's edit the real world before we create the simulation
RealWorld = ry.Config()
RealWorld.addFile("../../scenarios/challenge.g")

#you can also change the shape & size
RealWorld.getFrame("obj0").setColor([1.,0,0])
RealWorld.getFrame("obj0").setShape(ry.ST.box, [.04, .04, .15, .01])
# RealWorld.getFrame("obj0").setPosition([0., .2, 1.])
RealWorld.getFrame("obj0").setPosition([0., 0., .68])
RealWorld.getFrame("obj0").setQuaternion([0.707, 0.707, 0., 0.])

RealWorld.getFrame("obj0").setContact(1)

#remove some objects
for o in range(1,30):
    name = "obj%i" % o
#     print("deleting", name)
    RealWorld.delFrame(name)
    
    
# instantiate the simulation
S = RealWorld.simulation(ry.SimulatorEngine.bullet, True)
S.addSensor("camera")

# we're adding an "imp" to the simulation, which is a little process that can inject perturbations
# S.addImp(ry.ImpType.objectImpulses, ['obj0'], [])

# setup your model world
C = ry.Config()
C.addFile("../../scenarios/pandasTable.g")

obj = C.addFrame("object")
obj.setColor([1.,0,0]) # set the color of one objet to red!
obj.setShape(ry.ST.sphere, [.03]) # assume that we know the object shape

# obj.setQuaternion([1,0,1,0])
# obj.setShape(ry.ST.capsule, [.2,.02])
# obj.setColor([1,0,1])

D = C.view();
# Out:
# **ry-c++-log** ry.cpp:init_LogToPythonConsole:34(0) initializing ry log callback
#
# **ry-c++-log** util.cpp:initCmdLine:545(1) ** cmd line arguments: 'rai-pybind -python '
#
# **ry-c++-log** util.cpp:initCmdLine:549(1) ** run path: '/home/vasko/Documents/TUB3/AI_Robotics/robotics-course/course3-Simulation/05-grasp'
#
# **ry-c++-log** graph.cpp:initParameters:1379(1) ** parsed parameters:
# {python}
#
#
# ** INFO:ry.cpp:init_LogToPythonConsole:34(0) initializing ry log callback
# ** INFO:util.cpp:initCmdLine:545(1) ** cmd line arguments: 'rai-pybind -python '
# ** INFO:util.cpp:initCmdLine:549(1) ** run path: '/home/vasko/Documents/TUB3/AI_Robotics/robotics-course/course3-Simulation/05-grasp'
# ** INFO:graph.cpp:initParameters:1379(1) ** parsed parameters:
# {python}

# %%
def solve_komo_IK_grasping():
    IK = C.komo_IK(False)

    # encode grasping
    IK.addObjective([1.], 
                    ry.FS.positionRel, 
                    ["object", "R_gripperCenter"], 
                    ry.OT.eq, 
                    1e2,
                    [0.,0.,.0]);


    IK.addObjective([0.,1.], 
                    ry.FS.quaternionRel, 
                    ["object", "R_gripperCenter"], 
                    ry.OT.eq, 
                    [1.2e2],
                    [0.707, 0.707, 0., 0.]);


    IK.optimize()
#     IK.getReport()
    return IK.getPathFrames()

# %%
def grasping(KOMO = False):
    points = []
    tau = .01

    gripping = False
    grasped = False

    prev_contours = None
    prev_full_mask = None
    # small cheating, better intitialization
    objectPosition = RealWorld.frame("obj0").getPosition();

    for t in range(3000):
        time.sleep(tau)

        #grab sensor readings from the simulation
        q = S.get_q()

        # TOTAL CHEAT: grab the true position from the RealWorld
        objectPosition = RealWorld.frame("obj0").getPosition();
        objectRotation = RealWorld.frame("obj0").getQuaternion();
        obj.setPosition(objectPosition) # set the model object to percept
        obj.setQuaternion(objectRotation) # set the model object to percept
        
        C.setJointState(q); # set your robot model to match the real q

        y, J = C.evalFeature(ry.FS.positionDiff, ["R_gripperCenter", "object"])

    #     qdot = np.linalg.inv(J.T@J + 1e-3*np.eye(q.shape[0])) @ J.T @ (-5*y)

        komo_next_state = solve_komo_IK_grasping()[0]
#         komo_next_state = solve_komo_IK_grasping_relative()[0]
            
        C.setFrameState(komo_next_state)

        qdot = ( C.getJointState() - q ) /  (  40*tau )

        if not gripping and np.linalg.norm(y) < .01:
            print("Grasping")
            S.closeGripper("R_gripper", speed=1.)
            gripping = True

        if gripping and S.getGripperWidth("R_gripper") < 1e-2:
            print("FAILED!")
            S.openGripper("R_gripper", speed=1.)
            gripping = False
            return False

        if gripping and S.getGripperIsGrasping("R_gripper"):
            print("GRASPED!")
            grasped = True
            return True

        S.step(qdot, tau, ry.ControlMode.velocity)

# %%
# while (True):
#     grasped = grasping()
#     if not grasped:
#         print("Failiure grasping")
#         break;
#     released = lift_release()
#     if not released:
#         print("Failiure releasing")
#         break;

# %%
grasped = grasping()
# Out:
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00125 (kin:7.6e-05 coll:0 feat:0.000597 newton: 0.000144) setJointStateCount:29
#    sos:0.0316569 ineq:0 eq:0.0260366
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001073 (kin:6.9e-05 coll:0 feat:0.000483 newton: 0.000117) setJointStateCount:26
#    sos:0.0301747 ineq:0 eq:0.0261486
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001412 (kin:7.2e-05 coll:0 feat:0.00049 newton: 0.000429) setJointStateCount:25
#    sos:0.0287481 ineq:0 eq:0.0261336
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001013 (kin:6.2e-05 coll:0 feat:0.000452 newton: 0.000107) setJointStateCount:25
#    sos:0.0275382 ineq:0 eq:0.0261323
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001852 (kin:9.6e-05 coll:0 feat:0.000683 newton: 0.000178) setJointStateCount:25
#    sos:0.026371 ineq:0 eq:0.0260905
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001058 (kin:6.5e-05 coll:0 feat:0.000472 newton: 0.000119) setJointStateCount:25
#    sos:0.0253811 ineq:0 eq:0.0260467
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001466 (kin:7.9e-05 coll:0 feat:0.000512 newton: 0.000346) setJointStateCount:25
#    sos:0.0240903 ineq:0 eq:0.0260155
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.010855 (kin:0.000239 coll:0 feat:0.001815 newton: 0.005557) setJointStateCount:24
#    sos:0.0227622 ineq:0 eq:0.0260162
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001406 (kin:8.6e-05 coll:0 feat:0.000626 newton: 0.000151) setJointStateCount:24
#    sos:0.0215787 ineq:0 eq:0.025991
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001434 (kin:9e-05 coll:0 feat:0.000648 newton: 0.000149) setJointStateCount:24
#    sos:0.0205965 ineq:0 eq:0.0259916
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001367 (kin:7.7e-05 coll:0 feat:0.000601 newton: 0.000149) setJointStateCount:24
#    sos:0.0196516 ineq:0 eq:0.0259503
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001385 (kin:7.9e-05 coll:0 feat:0.000596 newton: 0.000138) setJointStateCount:23
#    sos:0.0187192 ineq:0 eq:0.0259484
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001362 (kin:8.7e-05 coll:0 feat:0.000606 newton: 0.000146) setJointStateCount:23
#    sos:0.017797 ineq:0 eq:0.0259437
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001346 (kin:8.1e-05 coll:0 feat:0.000597 newton: 0.00014) setJointStateCount:23
#    sos:0.016926 ineq:0 eq:0.0259237
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001498 (kin:9.6e-05 coll:0 feat:0.000688 newton: 0.000151) setJointStateCount:22
#    sos:0.0160713 ineq:0 eq:0.0260767
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001377 (kin:8.7e-05 coll:0 feat:0.000595 newton: 0.000148) setJointStateCount:22
#    sos:0.0152716 ineq:0 eq:0.0260532
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001353 (kin:8.7e-05 coll:0 feat:0.000608 newton: 0.000151) setJointStateCount:21
#    sos:0.0145054 ineq:0 eq:0.0261012
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001236 (kin:7.6e-05 coll:0 feat:0.000549 newton: 0.000134) setJointStateCount:21
#    sos:0.0137993 ineq:0 eq:0.026122
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001353 (kin:9.4e-05 coll:0 feat:0.000588 newton: 0.00014) setJointStateCount:21
#    sos:0.0130902 ineq:0 eq:0.0260646
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00146 (kin:9.7e-05 coll:0 feat:0.000616 newton: 0.000144) setJointStateCount:21
#    sos:0.0124591 ineq:0 eq:0.0260337
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.002045 (kin:9.1e-05 coll:0 feat:0.00059 newton: 0.000158) setJointStateCount:19
#    sos:0.0118633 ineq:0 eq:0.0259867
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001216 (kin:7.8e-05 coll:0 feat:0.000522 newton: 0.000132) setJointStateCount:19
#    sos:0.0113047 ineq:0 eq:0.0259642
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001245 (kin:7.8e-05 coll:0 feat:0.000545 newton: 0.000125) setJointStateCount:20
#    sos:0.0106839 ineq:0 eq:0.0260271
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.004125 (kin:0.000124 coll:0 feat:0.002681 newton: 0.000148) setJointStateCount:18
#    sos:0.010176 ineq:0 eq:0.0259863
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001256 (kin:7.9e-05 coll:0 feat:0.000527 newton: 0.000137) setJointStateCount:18
#    sos:0.00964266 ineq:0 eq:0.0259653
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001186 (kin:7.8e-05 coll:0 feat:0.000524 newton: 0.000127) setJointStateCount:18
#    sos:0.00919676 ineq:0 eq:0.0259565
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001697 (kin:7.6e-05 coll:0 feat:0.000993 newton: 0.000157) setJointStateCount:18
#    sos:0.00872965 ineq:0 eq:0.0259648
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000771 (kin:4.7e-05 coll:0 feat:0.000323 newton: 8.1e-05) setJointStateCount:18
#    sos:0.00829146 ineq:0 eq:0.0259312
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000872 (kin:4.8e-05 coll:0 feat:0.000393 newton: 8.1e-05) setJointStateCount:18
#    sos:0.0078788 ineq:0 eq:0.0259143
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000828 (kin:4.3e-05 coll:0 feat:0.000371 newton: 9.4e-05) setJointStateCount:17
#    sos:0.00751583 ineq:0 eq:0.0259679
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000881 (kin:5.3e-05 coll:0 feat:0.000374 newton: 8.8e-05) setJointStateCount:18
#    sos:0.00713693 ineq:0 eq:0.0258957
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000819 (kin:5e-05 coll:0 feat:0.000352 newton: 9.2e-05) setJointStateCount:17
#    sos:0.00677425 ineq:0 eq:0.0259105
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001012 (kin:6.4e-05 coll:0 feat:0.000397 newton: 8.5e-05) setJointStateCount:17
#    sos:0.00643947 ineq:0 eq:0.0259134
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000725 (kin:4.4e-05 coll:0 feat:0.000296 newton: 7.6e-05) setJointStateCount:16
#    sos:0.00612115 ineq:0 eq:0.0260561
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00089 (kin:4.9e-05 coll:0 feat:0.000405 newton: 0.000112) setJointStateCount:17
#    sos:0.00580788 ineq:0 eq:0.025897
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000668 (kin:3.8e-05 coll:0 feat:0.000284 newton: 7.2e-05) setJointStateCount:16
#    sos:0.00553658 ineq:0 eq:0.0260166
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000673 (kin:4e-05 coll:0 feat:0.00029 newton: 6.9e-05) setJointStateCount:16
#    sos:0.00525225 ineq:0 eq:0.025996
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000673 (kin:4.5e-05 coll:0 feat:0.000288 newton: 7e-05) setJointStateCount:16
#    sos:0.00499437 ineq:0 eq:0.0260012
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001231 (kin:4.5e-05 coll:0 feat:0.000367 newton: 7.9e-05) setJointStateCount:16
#    sos:0.00475008 ineq:0 eq:0.0259644
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000721 (kin:4.8e-05 coll:0 feat:0.000306 newton: 8.1e-05) setJointStateCount:15
#    sos:0.00452196 ineq:0 eq:0.0260269
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000643 (kin:3.6e-05 coll:0 feat:0.000276 newton: 6.8e-05) setJointStateCount:15
#    sos:0.00429963 ineq:0 eq:0.0260216
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000645 (kin:3.6e-05 coll:0 feat:0.000264 newton: 7.4e-05) setJointStateCount:15
#    sos:0.00406895 ineq:0 eq:0.0259515
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000781 (kin:4.4e-05 coll:0 feat:0.000375 newton: 8.9e-05) setJointStateCount:15
#    sos:0.00385929 ineq:0 eq:0.0259916
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000784 (kin:5.4e-05 coll:0 feat:0.000354 newton: 7.4e-05) setJointStateCount:15
#    sos:0.00368718 ineq:0 eq:0.025944
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000645 (kin:3.9e-05 coll:0 feat:0.000276 newton: 6.8e-05) setJointStateCount:15
#    sos:0.00349739 ineq:0 eq:0.0259338
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00063 (kin:3.5e-05 coll:0 feat:0.000263 newton: 6.8e-05) setJointStateCount:15
#    sos:0.00332933 ineq:0 eq:0.0259536
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000692 (kin:4.2e-05 coll:0 feat:0.000289 newton: 7.4e-05) setJointStateCount:15
#    sos:0.00315826 ineq:0 eq:0.0259043
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000639 (kin:3.6e-05 coll:0 feat:0.000268 newton: 7e-05) setJointStateCount:15
#    sos:0.00299961 ineq:0 eq:0.025952
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000782 (kin:4.9e-05 coll:0 feat:0.000328 newton: 7.8e-05) setJointStateCount:15
#    sos:0.00285665 ineq:0 eq:0.0258716
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000604 (kin:3.3e-05 coll:0 feat:0.000247 newton: 6.9e-05) setJointStateCount:14
#    sos:0.00271113 ineq:0 eq:0.0259042
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000851 (kin:4.8e-05 coll:0 feat:0.000296 newton: 0.000176) setJointStateCount:14
#    sos:0.00257996 ineq:0 eq:0.025901
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000598 (kin:3.5e-05 coll:0 feat:0.000252 newton: 6.2e-05) setJointStateCount:14
#    sos:0.00245451 ineq:0 eq:0.0258977
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000694 (kin:3.6e-05 coll:0 feat:0.00027 newton: 0.000106) setJointStateCount:13
#    sos:0.00233674 ineq:0 eq:0.0260013
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000714 (kin:4.4e-05 coll:0 feat:0.000279 newton: 6.9e-05) setJointStateCount:13
#    sos:0.00221346 ineq:0 eq:0.0259342
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000645 (kin:4e-05 coll:0 feat:0.000272 newton: 6.1e-05) setJointStateCount:13
#    sos:0.00210205 ineq:0 eq:0.0259631
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000627 (kin:3.6e-05 coll:0 feat:0.000252 newton: 6.3e-05) setJointStateCount:13
#    sos:0.00200391 ineq:0 eq:0.0259343
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.003694 (kin:0.000117 coll:0 feat:0.002587 newton: 0.0002) setJointStateCount:13
#    sos:0.00189922 ineq:0 eq:0.0259457
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00118 (kin:7.4e-05 coll:0 feat:0.000439 newton: 0.000106) setJointStateCount:13
#    sos:0.00180694 ineq:0 eq:0.0259109
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000927 (kin:5.7e-05 coll:0 feat:0.000405 newton: 9.1e-05) setJointStateCount:13
#    sos:0.00172276 ineq:0 eq:0.0258934
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000779 (kin:4.6e-05 coll:0 feat:0.000327 newton: 8e-05) setJointStateCount:13
#    sos:0.00163776 ineq:0 eq:0.0259229
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001271 (kin:7.2e-05 coll:0 feat:0.000619 newton: 8.7e-05) setJointStateCount:13
#    sos:0.0015546 ineq:0 eq:0.0258703
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000794 (kin:5.3e-05 coll:0 feat:0.000325 newton: 8.7e-05) setJointStateCount:13
#    sos:0.00147511 ineq:0 eq:0.0258724
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000837 (kin:4e-05 coll:0 feat:0.000299 newton: 0.000164) setJointStateCount:13
#    sos:0.00140146 ineq:0 eq:0.0258387
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000688 (kin:3.9e-05 coll:0 feat:0.000286 newton: 7.1e-05) setJointStateCount:13
#    sos:0.001345 ineq:0 eq:0.0258399
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000834 (kin:5.2e-05 coll:0 feat:0.000345 newton: 8.1e-05) setJointStateCount:12
#    sos:0.00127686 ineq:0 eq:0.0259541
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00327 (kin:0.000838 coll:0 feat:0.001996 newton: 9.9e-05) setJointStateCount:13
#    sos:0.00120662 ineq:0 eq:0.0258494
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000765 (kin:4.3e-05 coll:0 feat:0.000323 newton: 7.8e-05) setJointStateCount:13
#    sos:0.0011489 ineq:0 eq:0.0258485
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000578 (kin:3.2e-05 coll:0 feat:0.000241 newton: 5.8e-05) setJointStateCount:10
#    sos:0.00110534 ineq:0 eq:0.0289019
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000585 (kin:3e-05 coll:0 feat:0.000236 newton: 5.7e-05) setJointStateCount:10
#    sos:0.00105458 ineq:0 eq:0.0289383
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000961 (kin:0.000102 coll:0 feat:0.000243 newton: 5.7e-05) setJointStateCount:10
#    sos:0.000998922 ineq:0 eq:0.0287189
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000643 (kin:4.1e-05 coll:0 feat:0.000269 newton: 5.9e-05) setJointStateCount:10
#    sos:0.000956643 ineq:0 eq:0.0286593
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000602 (kin:3.5e-05 coll:0 feat:0.000256 newton: 5.8e-05) setJointStateCount:10
#    sos:0.000903625 ineq:0 eq:0.0283088
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000639 (kin:3.4e-05 coll:0 feat:0.000259 newton: 6.3e-05) setJointStateCount:10
#    sos:0.000865025 ineq:0 eq:0.0286806
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000561 (kin:3e-05 coll:0 feat:0.000226 newton: 5.4e-05) setJointStateCount:10
#    sos:0.000814975 ineq:0 eq:0.028403
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000597 (kin:3e-05 coll:0 feat:0.000229 newton: 5.3e-05) setJointStateCount:10
#    sos:0.000781041 ineq:0 eq:0.0283614
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000602 (kin:3e-05 coll:0 feat:0.000228 newton: 5.6e-05) setJointStateCount:10
#    sos:0.000740526 ineq:0 eq:0.0282736
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000602 (kin:3e-05 coll:0 feat:0.000243 newton: 8.9e-05) setJointStateCount:10
#    sos:0.00070076 ineq:0 eq:0.0280891
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000525 (kin:3.1e-05 coll:0 feat:0.0002 newton: 5.1e-05) setJointStateCount:8
#    sos:0.000670488 ineq:0 eq:0.0281937
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001241 (kin:2.8e-05 coll:0 feat:0.000201 newton: 5.3e-05) setJointStateCount:8
#    sos:0.000640411 ineq:0 eq:0.028008
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001268 (kin:0.000714 coll:0 feat:0.000231 newton: 6.4e-05) setJointStateCount:8
#    sos:0.000601676 ineq:0 eq:0.0281792
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000478 (kin:2.4e-05 coll:0 feat:0.000185 newton: 5.1e-05) setJointStateCount:8
#    sos:0.000570954 ineq:0 eq:0.0280552
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000591 (kin:3.3e-05 coll:0 feat:0.000209 newton: 5.3e-05) setJointStateCount:8
#    sos:0.00054786 ineq:0 eq:0.0278509
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000483 (kin:2.5e-05 coll:0 feat:0.000187 newton: 5e-05) setJointStateCount:8
#    sos:0.000519073 ineq:0 eq:0.0278286
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000433 (kin:2.6e-05 coll:0 feat:0.000166 newton: 4.6e-05) setJointStateCount:7
#    sos:0.000493589 ineq:0 eq:0.0274397
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000768 (kin:4.1e-05 coll:0 feat:0.000398 newton: 6.5e-05) setJointStateCount:8
#    sos:0.00046712 ineq:0 eq:0.0277532
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00048 (kin:2.5e-05 coll:0 feat:0.000194 newton: 5.1e-05) setJointStateCount:8
#    sos:0.000442029 ineq:0 eq:0.0277609
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000495 (kin:2.8e-05 coll:0 feat:0.000195 newton: 5.3e-05) setJointStateCount:8
#    sos:0.000422551 ineq:0 eq:0.0277178
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000816 (kin:2.7e-05 coll:0 feat:0.000521 newton: 4.6e-05) setJointStateCount:7
#    sos:0.000406619 ineq:0 eq:0.0275807
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000531 (kin:2.7e-05 coll:0 feat:0.000183 newton: 4.8e-05) setJointStateCount:7
#    sos:0.000382335 ineq:0 eq:0.0273305
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000618 (kin:2.5e-05 coll:0 feat:0.000178 newton: 4.6e-05) setJointStateCount:7
#    sos:0.000361339 ineq:0 eq:0.0273691
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000474 (kin:2.2e-05 coll:0 feat:0.000169 newton: 4.3e-05) setJointStateCount:7
#    sos:0.000347878 ineq:0 eq:0.0273758
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000449 (kin:2.5e-05 coll:0 feat:0.000169 newton: 4.6e-05) setJointStateCount:7
#    sos:0.000336402 ineq:0 eq:0.0271855
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000476 (kin:2.4e-05 coll:0 feat:0.000177 newton: 4.8e-05) setJointStateCount:7
#    sos:0.000312545 ineq:0 eq:0.027409
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000451 (kin:2.2e-05 coll:0 feat:0.000169 newton: 4.3e-05) setJointStateCount:7
#    sos:0.000294272 ineq:0 eq:0.0272148
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000497 (kin:2.9e-05 coll:0 feat:0.000181 newton: 4.9e-05) setJointStateCount:7
#    sos:0.000282796 ineq:0 eq:0.0273201
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000436 (kin:2.4e-05 coll:0 feat:0.000165 newton: 4.2e-05) setJointStateCount:7
#    sos:0.000268921 ineq:0 eq:0.0271092
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000503 (kin:2.6e-05 coll:0 feat:0.00019 newton: 5e-05) setJointStateCount:7
#    sos:0.000253952 ineq:0 eq:0.0274289
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000475 (kin:1.9e-05 coll:0 feat:0.000165 newton: 4.2e-05) setJointStateCount:7
#    sos:0.000238385 ineq:0 eq:0.0269833
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000559 (kin:3e-05 coll:0 feat:0.000205 newton: 5.8e-05) setJointStateCount:7
#    sos:0.000227741 ineq:0 eq:0.0269854
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000484 (kin:2.4e-05 coll:0 feat:0.000178 newton: 4.8e-05) setJointStateCount:7
#    sos:0.000215919 ineq:0 eq:0.0268284
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000436 (kin:2.2e-05 coll:0 feat:0.000165 newton: 4.4e-05) setJointStateCount:7
#    sos:0.000206476 ineq:0 eq:0.0268916
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000508 (kin:2.9e-05 coll:0 feat:0.000187 newton: 4.9e-05) setJointStateCount:7
#    sos:0.000206096 ineq:0 eq:0.0268054
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000428 (kin:2.3e-05 coll:0 feat:0.000168 newton: 4.7e-05) setJointStateCount:7
#    sos:0.000192134 ineq:0 eq:0.0269088
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000473 (kin:2.6e-05 coll:0 feat:0.000183 newton: 4.9e-05) setJointStateCount:7
#    sos:0.000178501 ineq:0 eq:0.0268216
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000515 (kin:4e-05 coll:0 feat:0.000199 newton: 4.5e-05) setJointStateCount:7
#    sos:0.000179379 ineq:0 eq:0.0267683
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000519 (kin:3.6e-05 coll:0 feat:0.000192 newton: 5.8e-05) setJointStateCount:7
#    sos:0.000162111 ineq:0 eq:0.0266429
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000473 (kin:2.5e-05 coll:0 feat:0.000173 newton: 4.3e-05) setJointStateCount:7
#    sos:0.000158916 ineq:0 eq:0.0269017
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000808 (kin:2.5e-05 coll:0 feat:0.000177 newton: 0.000384) setJointStateCount:7
#    sos:0.000147382 ineq:0 eq:0.026784
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000459 (kin:2.3e-05 coll:0 feat:0.00017 newton: 4.5e-05) setJointStateCount:7
#    sos:0.000145869 ineq:0 eq:0.0264993
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000432 (kin:2.4e-05 coll:0 feat:0.000166 newton: 4.6e-05) setJointStateCount:7
#    sos:0.000135426 ineq:0 eq:0.0266168
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000505 (kin:2.8e-05 coll:0 feat:0.000189 newton: 5.1e-05) setJointStateCount:6
#    sos:0.000131045 ineq:0 eq:0.0268335
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000456 (kin:2.3e-05 coll:0 feat:0.000171 newton: 4.3e-05) setJointStateCount:7
#    sos:0.000124382 ineq:0 eq:0.0265831
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000476 (kin:2.6e-05 coll:0 feat:0.000175 newton: 4.4e-05) setJointStateCount:6
#    sos:0.000116334 ineq:0 eq:0.0267415
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000461 (kin:2.3e-05 coll:0 feat:0.000173 newton: 4.5e-05) setJointStateCount:7
#    sos:0.000113747 ineq:0 eq:0.0266034
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000409 (kin:2e-05 coll:0 feat:0.000149 newton: 4.8e-05) setJointStateCount:6
#    sos:0.000103323 ineq:0 eq:0.0267638
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000384 (kin:2e-05 coll:0 feat:0.00015 newton: 3.6e-05) setJointStateCount:6
#    sos:9.85197e-05 ineq:0 eq:0.0263119
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000479 (kin:2.3e-05 coll:0 feat:0.000159 newton: 4.1e-05) setJointStateCount:6
#    sos:9.75775e-05 ineq:0 eq:0.0270142
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000414 (kin:2.3e-05 coll:0 feat:0.000157 newton: 4.2e-05) setJointStateCount:6
#    sos:9.12791e-05 ineq:0 eq:0.0266977
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000405 (kin:2.2e-05 coll:0 feat:0.000151 newton: 4e-05) setJointStateCount:6
#    sos:8.82131e-05 ineq:0 eq:0.0267661
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000514 (kin:3.1e-05 coll:0 feat:0.000184 newton: 5e-05) setJointStateCount:6
#    sos:8.19152e-05 ineq:0 eq:0.0267012
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000418 (kin:2.1e-05 coll:0 feat:0.000156 newton: 5.7e-05) setJointStateCount:6
#    sos:7.72829e-05 ineq:0 eq:0.0271567
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000438 (kin:2e-05 coll:0 feat:0.000158 newton: 4.2e-05) setJointStateCount:6
#    sos:7.64213e-05 ineq:0 eq:0.0262307
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000649 (kin:1.6e-05 coll:0 feat:0.000318 newton: 3.4e-05) setJointStateCount:5
#    sos:7.10394e-05 ineq:0 eq:0.0265553
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000505 (kin:3.1e-05 coll:0 feat:0.000179 newton: 4.2e-05) setJointStateCount:6
#    sos:6.91929e-05 ineq:0 eq:0.027063
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000426 (kin:2.1e-05 coll:0 feat:0.000159 newton: 4.1e-05) setJointStateCount:6
#    sos:7.32391e-05 ineq:0 eq:0.0268653
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00039 (kin:1.9e-05 coll:0 feat:0.000149 newton: 3.9e-05) setJointStateCount:6
#    sos:7.04235e-05 ineq:0 eq:0.0264896
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001037 (kin:2.8e-05 coll:0 feat:0.000615 newton: 4.7e-05) setJointStateCount:6
#    sos:5.60287e-05 ineq:0 eq:0.0265739
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000403 (kin:2.1e-05 coll:0 feat:0.00015 newton: 3.9e-05) setJointStateCount:6
#    sos:6.11739e-05 ineq:0 eq:0.0265558
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000439 (kin:2.6e-05 coll:0 feat:0.000157 newton: 4.3e-05) setJointStateCount:6
#    sos:5.76851e-05 ineq:0 eq:0.0268052
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000375 (kin:1.9e-05 coll:0 feat:0.000131 newton: 3.6e-05) setJointStateCount:5
#    sos:5.05906e-05 ineq:0 eq:0.02619
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000768 (kin:3.9e-05 coll:0 feat:0.000164 newton: 4e-05) setJointStateCount:6
#    sos:5.17134e-05 ineq:0 eq:0.0267407
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000413 (kin:2.1e-05 coll:0 feat:0.000148 newton: 4e-05) setJointStateCount:6
#    sos:4.60562e-05 ineq:0 eq:0.0267522
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000357 (kin:1.5e-05 coll:0 feat:0.000127 newton: 3.4e-05) setJointStateCount:5
#    sos:4.84519e-05 ineq:0 eq:0.0265334
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000399 (kin:2.2e-05 coll:0 feat:0.000139 newton: 3.7e-05) setJointStateCount:5
#    sos:5.00336e-05 ineq:0 eq:0.0261117
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000405 (kin:1.8e-05 coll:0 feat:0.000155 newton: 3.8e-05) setJointStateCount:6
#    sos:3.99952e-05 ineq:0 eq:0.026337
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000355 (kin:1.7e-05 coll:0 feat:0.000126 newton: 3.3e-05) setJointStateCount:5
#    sos:4.10347e-05 ineq:0 eq:0.0262782
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000439 (kin:2.4e-05 coll:0 feat:0.000159 newton: 4.6e-05) setJointStateCount:6
#    sos:3.80075e-05 ineq:0 eq:0.0266061
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000564 (kin:2.6e-05 coll:0 feat:0.000195 newton: 4e-05) setJointStateCount:5
#    sos:3.90654e-05 ineq:0 eq:0.0260695
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000445 (kin:2.3e-05 coll:0 feat:0.000152 newton: 4.2e-05) setJointStateCount:6
#    sos:3.66919e-05 ineq:0 eq:0.0260531
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000481 (kin:2.9e-05 coll:0 feat:0.000163 newton: 4.7e-05) setJointStateCount:5
#    sos:3.65977e-05 ineq:0 eq:0.027276
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00095 (kin:2.7e-05 coll:0 feat:0.000157 newton: 0.000481) setJointStateCount:5
#    sos:2.87094e-05 ineq:0 eq:0.0265995
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000243 (kin:1e-05 coll:0 feat:8.3e-05 newton: 2.2e-05) setJointStateCount:3
#    sos:3.28599e-05 ineq:0 eq:0.0332587
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000367 (kin:1.8e-05 coll:0 feat:0.000131 newton: 3.6e-05) setJointStateCount:5
#    sos:4.48127e-05 ineq:0 eq:0.0261944
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000485 (kin:3e-05 coll:0 feat:0.000157 newton: 4.3e-05) setJointStateCount:5
#    sos:3.00587e-05 ineq:0 eq:0.0264157
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000433 (kin:2.4e-05 coll:0 feat:0.000145 newton: 3.5e-05) setJointStateCount:5
#    sos:3.1204e-05 ineq:0 eq:0.0263726
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000366 (kin:1.8e-05 coll:0 feat:0.000131 newton: 3.4e-05) setJointStateCount:5
#    sos:2.84695e-05 ineq:0 eq:0.0262599
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00025 (kin:1.1e-05 coll:0 feat:8.6e-05 newton: 2.1e-05) setJointStateCount:3
#    sos:2.33025e-05 ineq:0 eq:0.0345851
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000544 (kin:3e-05 coll:0 feat:0.000166 newton: 5.6e-05) setJointStateCount:3
#    sos:2.06927e-05 ineq:0 eq:0.0338941
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000267 (kin:1.2e-05 coll:0 feat:8.7e-05 newton: 2e-05) setJointStateCount:3
#    sos:2.52186e-05 ineq:0 eq:0.0317607
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000377 (kin:2e-05 coll:0 feat:0.00013 newton: 3.5e-05) setJointStateCount:5
#    sos:2.48538e-05 ineq:0 eq:0.0263495
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00042 (kin:2e-05 coll:0 feat:0.000165 newton: 3.4e-05) setJointStateCount:5
#    sos:3.10347e-05 ineq:0 eq:0.0260832
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000415 (kin:2.2e-05 coll:0 feat:0.000145 newton: 3.9e-05) setJointStateCount:5
#    sos:2.57337e-05 ineq:0 eq:0.0263689
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000261 (kin:1.1e-05 coll:0 feat:8.5e-05 newton: 2.1e-05) setJointStateCount:3
#    sos:1.75415e-05 ineq:0 eq:0.0325628
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000279 (kin:1.2e-05 coll:0 feat:8.9e-05 newton: 2.4e-05) setJointStateCount:3
#    sos:1.54479e-05 ineq:0 eq:0.0320301
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000409 (kin:2.1e-05 coll:0 feat:0.000148 newton: 3.8e-05) setJointStateCount:5
#    sos:2.46441e-05 ineq:0 eq:0.0266103
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000286 (kin:1.3e-05 coll:0 feat:9.4e-05 newton: 2.4e-05) setJointStateCount:3
#    sos:1.87143e-05 ineq:0 eq:0.0330142
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000357 (kin:1.7e-05 coll:0 feat:0.00013 newton: 3e-05) setJointStateCount:5
#    sos:2.26879e-05 ineq:0 eq:0.02647
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.001048 (kin:2e-05 coll:0 feat:0.000137 newton: 3.7e-05) setJointStateCount:5
#    sos:1.68272e-05 ineq:0 eq:0.0261245
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000323 (kin:1.5e-05 coll:0 feat:0.000114 newton: 2.9e-05) setJointStateCount:4
#    sos:1.30925e-05 ineq:0 eq:0.0304651
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000427 (kin:2e-05 coll:0 feat:0.000141 newton: 3.7e-05) setJointStateCount:5
#    sos:1.65797e-05 ineq:0 eq:0.0262557
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000265 (kin:1.2e-05 coll:0 feat:8.8e-05 newton: 2.3e-05) setJointStateCount:3
#    sos:2.48128e-05 ineq:0 eq:0.0329369
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000306 (kin:1.2e-05 coll:0 feat:8.6e-05 newton: 2e-05) setJointStateCount:3
#    sos:1.34207e-05 ineq:0 eq:0.033745
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000273 (kin:1.3e-05 coll:0 feat:9e-05 newton: 2.2e-05) setJointStateCount:3
#    sos:9.94808e-06 ineq:0 eq:0.0328516
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000286 (kin:1.1e-05 coll:0 feat:8.3e-05 newton: 2.1e-05) setJointStateCount:3
#    sos:1.11071e-05 ineq:0 eq:0.0312128
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.00036 (kin:1.8e-05 coll:0 feat:0.000101 newton: 2.3e-05) setJointStateCount:3
#    sos:1.58174e-05 ineq:0 eq:0.0291894
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000265 (kin:1.1e-05 coll:0 feat:8.6e-05 newton: 2.2e-05) setJointStateCount:3
#    sos:1.39035e-05 ineq:0 eq:0.0311243
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000281 (kin:1.3e-05 coll:0 feat:9e-05 newton: 2.1e-05) setJointStateCount:3
#    sos:1.19154e-05 ineq:0 eq:0.0320153
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000274 (kin:1.2e-05 coll:0 feat:8.8e-05 newton: 2.2e-05) setJointStateCount:3
#    sos:2.04776e-05 ineq:0 eq:0.0293798
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000901 (kin:1.3e-05 coll:0 feat:9.1e-05 newton: 2.2e-05) setJointStateCount:3
#    sos:1.0204e-05 ineq:0 eq:0.0290392
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000288 (kin:1.3e-05 coll:0 feat:9.4e-05 newton: 2.3e-05) setJointStateCount:3
#    sos:1.0638e-05 ineq:0 eq:0.0288284
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000287 (kin:1.2e-05 coll:0 feat:9.4e-05 newton: 2.2e-05) setJointStateCount:3
#    sos:1.76211e-05 ineq:0 eq:0.0336133
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000484 (kin:3.1e-05 coll:0 feat:0.000175 newton: 4.1e-05) setJointStateCount:5
#    sos:1.66885e-05 ineq:0 eq:0.0260621
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000292 (kin:1.3e-05 coll:0 feat:9.6e-05 newton: 2.3e-05) setJointStateCount:3
#    sos:2.28245e-05 ineq:0 eq:0.0284477
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000295 (kin:1.3e-05 coll:0 feat:0.0001 newton: 2.3e-05) setJointStateCount:3
#    sos:1.10751e-05 ineq:0 eq:0.032914
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000764 (kin:0.000107 coll:0 feat:0.000474 newton: 2.2e-05) setJointStateCount:3
#    sos:9.59596e-06 ineq:0 eq:0.0285881
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000704 (kin:2.8e-05 coll:0 feat:0.000265 newton: 5.1e-05) setJointStateCount:3
#    sos:1.2754e-05 ineq:0 eq:0.0315003
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000567 (kin:2.2e-05 coll:0 feat:0.000213 newton: 3.4e-05) setJointStateCount:3
#    sos:1.09105e-05 ineq:0 eq:0.0328144
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000478 (kin:2e-05 coll:0 feat:0.000158 newton: 3.5e-05) setJointStateCount:3
#    sos:1.02947e-05 ineq:0 eq:0.0333494
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000557 (kin:2.3e-05 coll:0 feat:0.000166 newton: 4e-05) setJointStateCount:3
#    sos:1.16056e-05 ineq:0 eq:0.0325968
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000471 (kin:2.1e-05 coll:0 feat:0.00016 newton: 3.7e-05) setJointStateCount:3
#    sos:8.43107e-06 ineq:0 eq:0.0313418
# ** KOMO::run solver:dense collisions:0 x-dim:14 T:1 k:1 phases:1 stepsPerPhase:1 tau:1  #timeSlices:2 #totalDOFs:14 #frames:220
# ** optimization time:0.000465 (kin:2e-05 coll:0 feat:0.000161 newton: 3.7e-05) setJointStateCount:3
#    sos:1.39787e-05 ineq:0 eq:0.0296782
